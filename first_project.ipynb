# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Importing of our Data

# %%
df = pd.read_csv('C:\VS_code\DataProject\GlobalLandTemperaturesByCity.csv')

# %% [markdown]
#  Now we will see the head of the data

# %%
df.head()
# Out:
#            dt  AverageTemperature  AverageTemperatureUncertainty   City  \
# 0  1743-11-01               6.068                          1.737  Århus
# 1  1743-12-01                 NaN                            NaN  Århus
# 2  1744-01-01                 NaN                            NaN  Århus
# 3  1744-02-01                 NaN                            NaN  Århus
# 4  1744-03-01                 NaN                            NaN  Århus
#
#    Country Latitude Longitude
# 0  Denmark   57.05N    10.33E
# 1  Denmark   57.05N    10.33E
# 2  Denmark   57.05N    10.33E
# 3  Denmark   57.05N    10.33E
# 4  Denmark   57.05N    10.33E

# %%
df.columns
# Out:
# Index(['dt', 'AverageTemperature', 'AverageTemperatureUncertainty', 'City',
#        'Country', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
df.dropna(axis = 0)
# Out:
#             Avr_temp  Avr_Temp_U    City      Country Latitude Longitude
# Date
# 1743-11-01     6.068       1.737   Århus      Denmark   57.05N    10.33E
# 1744-04-01     5.788       3.624   Århus      Denmark   57.05N    10.33E
# 1744-05-01    10.644       1.283   Århus      Denmark   57.05N    10.33E
# 1744-06-01    14.051       1.347   Århus      Denmark   57.05N    10.33E
# 1744-07-01    16.082       1.396   Århus      Denmark   57.05N    10.33E
# ...              ...         ...     ...          ...      ...       ...
# 2013-04-01     7.710       0.182  Zwolle  Netherlands   52.24N     5.26E
# 2013-05-01    11.464       0.236  Zwolle  Netherlands   52.24N     5.26E
# 2013-06-01    15.043       0.261  Zwolle  Netherlands   52.24N     5.26E
# 2013-07-01    18.775       0.193  Zwolle  Netherlands   52.24N     5.26E
# 2013-08-01    18.025       0.298  Zwolle  Netherlands   52.24N     5.26E
#
# [8235082 rows x 6 columns]

# %%
df = df.rename(columns = {'dt':'Date', 'AverageTemperature':'Avr_temp', 'AverageTemperatureUncertainty':'Avr_Temp_U'})

# %%
df.head()
# Out:
#          Date  Avr_temp  Avr_Temp_U   City  Country Latitude Longitude
# 0  1743-11-01     6.068       1.737  Århus  Denmark   57.05N    10.33E
# 1  1743-12-01       NaN         NaN  Århus  Denmark   57.05N    10.33E
# 2  1744-01-01       NaN         NaN  Århus  Denmark   57.05N    10.33E
# 3  1744-02-01       NaN         NaN  Århus  Denmark   57.05N    10.33E
# 4  1744-03-01       NaN         NaN  Århus  Denmark   57.05N    10.33E

# %%
df['Date'] = pd.to_datetime(df['Date'])
df.set_index('Date', inplace = True)

# %%
df.index
# Out:
# DatetimeIndex(['1743-11-01', '1743-12-01', '1744-01-01', '1744-02-01',
#                '1744-03-01', '1744-04-01', '1744-05-01', '1744-06-01',
#                '1744-07-01', '1744-08-01',
#                ...
#                '2012-12-01', '2013-01-01', '2013-02-01', '2013-03-01',
#                '2013-04-01', '2013-05-01', '2013-06-01', '2013-07-01',
#                '2013-08-01', '2013-09-01'],
#               dtype='datetime64[ns]', name='Date', length=8599212, freq=None)

# %%
df = df.dropna(axis = 0)

# %%
df.head()
# Out:
#             Avr_temp  Avr_Temp_U   City  Country Latitude Longitude
# Date
# 1743-11-01     6.068       1.737  Århus  Denmark   57.05N    10.33E
# 1744-04-01     5.788       3.624  Århus  Denmark   57.05N    10.33E
# 1744-05-01    10.644       1.283  Århus  Denmark   57.05N    10.33E
# 1744-06-01    14.051       1.347  Århus  Denmark   57.05N    10.33E
# 1744-07-01    16.082       1.396  Århus  Denmark   57.05N    10.33E

# %%
df.describe()
# Out:
#            Avr_temp    Avr_Temp_U
# count  8.235082e+06  8.235082e+06
# mean   1.672743e+01  1.028575e+00
# std    1.035344e+01  1.129733e+00
# min   -4.270400e+01  3.400000e-02
# 25%    1.029900e+01  3.370000e-01
# 50%    1.883100e+01  5.910000e-01
# 75%    2.521000e+01  1.349000e+00
# max    3.965100e+01  1.539600e+01

# %%
df['Year'] = df.index.year

# %%
df.head()
# Out:
#             Avr_temp  Avr_Temp_U   City  Country Latitude Longitude  Year
# Date
# 1743-11-01     6.068       1.737  Århus  Denmark   57.05N    10.33E  1743
# 1744-04-01     5.788       3.624  Århus  Denmark   57.05N    10.33E  1744
# 1744-05-01    10.644       1.283  Århus  Denmark   57.05N    10.33E  1744
# 1744-06-01    14.051       1.347  Århus  Denmark   57.05N    10.33E  1744
# 1744-07-01    16.082       1.396  Århus  Denmark   57.05N    10.33E  1744

# %%
df.describe()
# Out:
#            Avr_temp    Avr_Temp_U          Year
# count  8.235082e+06  8.235082e+06  8.235082e+06
# mean   1.672743e+01  1.028575e+00  1.910834e+03
# std    1.035344e+01  1.129733e+00  6.419609e+01
# min   -4.270400e+01  3.400000e-02  1.743000e+03
# 25%    1.029900e+01  3.370000e-01  1.865000e+03
# 50%    1.883100e+01  5.910000e-01  1.915000e+03
# 75%    2.521000e+01  1.349000e+00  1.964000e+03
# max    3.965100e+01  1.539600e+01  2.013000e+03

# %%
df = df.loc['1980':'2013']
df.describe()
# Out:
#            Avr_temp    Avr_Temp_U          Year
# count  1.418480e+06  1.418480e+06  1.418480e+06
# mean   1.828311e+01  3.528441e-01  1.996342e+03
# std    9.928447e+00  1.914387e-01  9.723045e+00
# min   -3.844700e+01  3.600000e-02  1.980000e+03
# 25%    1.250600e+01  2.320000e-01  1.988000e+03
# 50%    2.067600e+01  3.090000e-01  1.996000e+03
# 75%    2.619500e+01  4.190000e-01  2.005000e+03
# max    3.915600e+01  5.181000e+00  2.013000e+03

# %%
df.columns
# Out:
# Index(['Avr_temp', 'Avr_Temp_U', 'City', 'Country', 'Latitude', 'Longitude',
#        'Year'],
#       dtype='object')

# %%
df[['Country','Avr_temp']].groupby('Country').mean().sort_values('Avr_temp')
# Out:
#                Avr_temp
# Country
# Mongolia      -2.157579
# Iceland        2.114478
# Russia         4.263936
# Norway         4.403986
# Finland        4.636715
# ...                 ...
# Mali          28.230102
# Burkina Faso  28.421298
# Sudan         28.613168
# Niger         28.717713
# Djibouti      29.721559
#
# [159 rows x 1 columns]

# %%
new = df[['Country']]

# %%
new.dtypes
# Out:
# Country    object
# dtype: object

# %%
df[['Country','Avr_temp']].groupby('Country').mean().sort_values('Avr_temp').plot(figsize =(4,3))
# Out:
# <Axes: xlabel='Country'>
